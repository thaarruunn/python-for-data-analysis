# %% [markdown]
# <strong>Matplotlib full course</strong>

# %% [markdown]
# *basic terms:*
#
# *the canvas your working on is called as Figure*
#
# *the region occupied by a graph when it is plotted on a figure is called as Axes*
#
# *figure --> axes --> axis*
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
plt.figure()

# %% [markdown]
# *usually in the industry , a figure and an axis is created together!*

# %%
fig, ax = plt.subplots()

# %% [markdown]
# *Figure*
# +
# *One Axes*

# %%
fig, ax = plt.subplots(2,2)
#create as many figures and axes.

# %%
#professionals usually prefer :

fig, ax = plt.subplots()

ax.plot(x,y)

# %%
ax.set_title("Sales") #used by professionals
ax.set_title("Sales")
ax.set_xlabel("Month")

# %% [markdown]
# *Everything belongs to the Axes because the graph owns the labels Not the Figure*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Why do Data Scientists need multiple Axes?*
#
# *Because real analysis rarely depends on ONE chart.*

# %% [markdown]
# *your question:*
#
# *"Which platform is performing best?"*
#
# *Can one graph answer that?*
#
# *No.*
#
# *You need:*
#
# *MULTIPLE graphs answering even a single question*
