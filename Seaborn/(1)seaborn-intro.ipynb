# %% [markdown]
# --
# A guide to SeaBorn

# %% [markdown]
# <strong>Why Seaborn Exists

# %% [markdown]
# *purpose:*
#
# *Built on top of Matplotlib.*
#
# *Designed for statistical visualization and Exploratory Data Analysis (EDA).*
#
# *Works naturally with Pandas DataFrames.*

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <strong>the three pillars of SeaBorn

# %% [markdown]
# *(1) Statistical Visualization:*
#
# Means
#
# Distributions
#
# Correlations
#
# Regression
#
# Confidence Intervals
#
# *(2)Beautiful Defaults:*
#
# Clean themes
#
# Better colours
#
# Minimal customization needed
#
# *(3)Pandas Integration:*
#
# Uses data=df
#
# Uses column names (x="column", y="column")

# %% [markdown]
# <strong>workflow of Seaborn

# %% [markdown]
# Business Question
#
#         ↓
#
# Choose Variables
#
#         ↓
#
# Choose Seaborn Plot
#
#         ↓
#
# Customize with Matplotlib
#
#         ↓
#
# Interpret Results
#
#         ↓
#
# Business Insight
