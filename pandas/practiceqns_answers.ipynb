# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\titan\OneDrive\Desktop\practicedata.csv")

# %%
#Display the first 10 rows.

df.head(10)
# Out:
#    order_id customer_id       platform       city       category  quantity  \
# 0     10001       C1024        Blinkit  Hyderabad         Fruits         6
# 1     10002       C1030        Blinkit  Bengaluru  Personal Care         1
# 2     10003       C1157            NaN    Chennai      Beverages         4
# 3     10004       C1299  BigBasket Now     Mumbai          Dairy         4
# 4     10005       C1262  BigBasket Now  Bengaluru      Household         6
# 5     10006       C1047      Instamart      Delhi  Personal Care         2
# 6     10007       C1252        Blinkit  Bengaluru      Household         5
# 7     10008       C1220      Instamart       Pune          fruit         6
# 8     10009       C1093      Instamart     Mumbai         Fruits         3
# 9     10010       C1053  BigBasket Now       Pune         Snacks         1
#
#     mrp  selling_price  discount_percent  delivery_fee  promised_time  \
# 0   703         667.85                 5          49.0             25
# ...

# %%
#Display the last 10 rows.

df.tail(10)
# Out:
#       order_id customer_id       platform       city    category  quantity  \
# 1010     10011       C1077        Blinkit     Mumbai   Beverages         1
# 1011     10012       C1238  BigBasket Now      Delhi       Dairy         2
# 1012     10013       C1185          Zepto       Pune   Beverages         1
# 1013     10014       C1168          Zepto  Hyderabad   Household         4
# 1014     10015       C1132          Zepto       Pune   Beverages         6
# 1015     10016       C1000  BigBasket Now       Pune       Dairy         2
# 1016     10017       C1205        Blinkit       Pune  Vegetables         3
# 1017     10018       C1280          Zepto    Chennai      Fruits         2
# 1018     10019       C1166      Instamart        NaN      Snacks         3
# 1019     10020       C1093        Blinkit  Bengaluru  Vegetables         3
#
#        mrp  selling_price  discount_percent  delivery_fee  promised_time  \
# ...

# %%
#no of rows and columns

df.shape #(row,column)
# Out:
# (1020, 19)

# %%
#all column names
df.columns
# Out:
# Index(['order_id', 'customer_id', 'platform', 'city', 'category', 'quantity',
#        'mrp', 'selling_price', 'discount_percent', 'delivery_fee',
#        'promised_time', 'delivery_time', 'order_value', 'payment_mode',
#        'membership', 'coupon_used', 'weekend', 'rating', 'delivery_partner'],
#       dtype='object')

# %%
#Use info() and summarize what you observe.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1020 non-null   int64
#  1   customer_id       1020 non-null   object
#  2   platform          995 non-null    object
#  3   city              994 non-null    object
#  4   category          1020 non-null   object
#  5   quantity          1020 non-null   int64
#  6   mrp               1020 non-null   int64
#  7   selling_price     1020 non-null   float64
#  8   discount_percent  1020 non-null   int64
#  9   delivery_fee      995 non-null    float64
#  10  promised_time     1020 non-null   int64
#  11  delivery_time     1020 non-null   int64
#  12  order_value       1020 non-null   float64
#  13  payment_mode      1020 non-null   object
#  14  membership        682 non-null    object
#  15  coupon_used       1020 non-null   object
# ...

# %%
df.describe()
# Out:
#            order_id     quantity          mrp  selling_price  \
# count   1020.000000  1020.000000  1020.000000    1020.000000
# mean   10490.892157     4.453922   619.950000     527.948480
# std      293.939033     2.291520   334.733055     295.886884
# min    10001.000000     1.000000    40.000000      28.700000
# 25%    10235.750000     2.000000   327.750000     269.025000
# 50%    10490.500000     4.000000   615.000000     519.650000
# 75%    10745.250000     6.250000   915.000000     760.337500
# max    11000.000000     8.000000  1197.000000    1180.000000
#
#        discount_percent  delivery_fee  promised_time  delivery_time  \
# count       1020.000000    995.000000    1020.000000    1020.000000
# mean          15.127451     31.925628      20.029412      26.214706
# std           10.045697     19.423132       6.955566       9.936204
# min            0.000000      0.000000      10.000000       5.000000
# 25%            5.000000     19.000000      15.000000      19.000000
# ...

# %%
df.memory_usage()
# Out:
# Index                132
# order_id            8160
# customer_id         8160
# platform            8160
# city                8160
# category            8160
# quantity            8160
# mrp                 8160
# selling_price       8160
# discount_percent    8160
# delivery_fee        8160
# promised_time       8160
# delivery_time       8160
# order_value         8160
# payment_mode        8160
# membership          8160
# coupon_used         8160
# weekend             8160
# rating              8160
# delivery_partner    8160
# dtype: int64

# %%
#columns with the most NULL values
df.isnull().sum().idxmax()
# Out:
# 'membership'

# %%
#How many unique platforms are present before cleaning?

df['platform'].nunique()
df['platform'].unique()
# Out:
# array(['Blinkit', nan, 'BigBasket Now', 'Instamart', 'Zepto', 'blinkit'],
#       dtype=object)

# %%
#How many unique cities are present before cleaning?

df['city'].unique()
# Out:
# array(['Hyderabad', 'Bengaluru', 'Chennai', 'Mumbai', 'Delhi', 'Pune',
#        nan, ' Chennai '], dtype=object)

# %%
#Display the frequency of every category.
df['platform'].value_counts()
# Out:
# platform
# BigBasket Now    253
# Zepto            253
# Blinkit          240
# Instamart        229
# blinkit           20
# Name: count, dtype: int64

# %% [markdown]
# Identify at least one suspicious data quality issues.
# (1)unclean data

# %%
#Show only order_id, platform and order_value.
df[['order_id','platform','order_value']]
# Out:
#       order_id       platform  order_value
# 0        10001        Blinkit       667.85
# 1        10002        Blinkit      3724.00
# 2        10003            NaN       536.00
# 3        10004  BigBasket Now      2562.00
# 4        10005  BigBasket Now      4025.60
# ...        ...            ...          ...
# 1015     10016  BigBasket Now       795.60
# 1016     10017        Blinkit       720.00
# 1017     10018          Zepto      2274.75
# 1018     10019      Instamart      3067.20
# 1019     10020        Blinkit      1779.20
#
# [1020 rows x 3 columns]

# %%
#Display all orders from Chennai.

df[df['city']=='Chennai']
# Out:
#       order_id customer_id       platform     city    category  quantity  \
# 2        10003       C1157            NaN  Chennai   Beverages         4
# 17       10018       C1280          Zepto  Chennai      Fruits         2
# 26       10027       C1042          Zepto  Chennai       Dairy         2
# 27       10028       C1082            NaN  Chennai  Vegetables         4
# 30       10031       C1124      Instamart  Chennai      Snacks         3
# ...        ...         ...            ...      ...         ...       ...
# 988      10989       C1210  BigBasket Now  Chennai   Beverages         1
# 993      10994       C1146          Zepto  Chennai      Snacks         4
# 998      10999       C1068            NaN  Chennai      Snacks         7
# 1002     10003       C1157            NaN  Chennai   Beverages         4
# 1017     10018       C1280          Zepto  Chennai      Fruits         2
#
#        mrp  selling_price  discount_percent  delivery_fee  promised_time  \
# ...

# %%
#Display all Blinkit orders.

df[df['platform']=='Blinkit']
# Out:
#       order_id customer_id platform       city       category  quantity   mrp  \
# 0        10001       C1024  Blinkit  Hyderabad         Fruits         6   703
# 1        10002       C1030  Blinkit  Bengaluru  Personal Care         1   532
# 6        10007       C1252  Blinkit  Bengaluru      Household         5   767
# 10       10011       C1077  Blinkit     Mumbai      Beverages         1   147
# 16       10017       C1205  Blinkit       Pune     Vegetables         3   720
# ...        ...         ...      ...        ...            ...       ...   ...
# 1001     10002       C1030  Blinkit  Bengaluru  Personal Care         1   532
# 1006     10007       C1252  Blinkit  Bengaluru      Household         5   767
# 1010     10011       C1077  Blinkit     Mumbai      Beverages         1   147
# 1016     10017       C1205  Blinkit       Pune     Vegetables         3   720
# 1019     10020       C1093  Blinkit  Bengaluru     Vegetables         3  1112
#
# ...

# %%
#Orders where delivery time is greater than promised time

df[df['delivery_time']>df['promised_time']]
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 0        10001       C1024        Blinkit  Hyderabad         Fruits         6
# 1        10002       C1030        Blinkit  Bengaluru  Personal Care         1
# 2        10003       C1157            NaN    Chennai      Beverages         4
# 3        10004       C1299  BigBasket Now     Mumbai          Dairy         4
# 8        10009       C1093      Instamart     Mumbai         Fruits         3
# ...        ...         ...            ...        ...            ...       ...
# 1014     10015       C1132          Zepto       Pune      Beverages         6
# 1015     10016       C1000  BigBasket Now       Pune          Dairy         2
# 1016     10017       C1205        Blinkit       Pune     Vegetables         3
# 1018     10019       C1166      Instamart        NaN         Snacks         3
# 1019     10020       C1093        Blinkit  Bengaluru     Vegetables         3
#
# ...

# %%
#Orders from Chennai OR Mumbai.

df[(df['city']=='Chennai') |(df['city']=='Mumbai')]
# Out:
#       order_id customer_id       platform     city   category  quantity   mrp  \
# 2        10003       C1157            NaN  Chennai  Beverages         4   335
# 3        10004       C1299  BigBasket Now   Mumbai      Dairy         4   915
# 8        10009       C1093      Instamart   Mumbai     Fruits         3   517
# 10       10011       C1077        Blinkit   Mumbai  Beverages         1   147
# 17       10018       C1280          Zepto  Chennai     Fruits         2  1011
# ...        ...         ...            ...      ...        ...       ...   ...
# 1002     10003       C1157            NaN  Chennai  Beverages         4   335
# 1003     10004       C1299  BigBasket Now   Mumbai      Dairy         4   915
# 1008     10009       C1093      Instamart   Mumbai     Fruits         3   517
# 1010     10011       C1077        Blinkit   Mumbai  Beverages         1   147
# 1017     10018       C1280          Zepto  Chennai     Fruits         2  1011
#
# ...

# %%
#Orders where membership is Gold.

df[df['membership']=='Gold']
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 0        10001       C1024        Blinkit  Hyderabad         Fruits         6
# 1        10002       C1030        Blinkit  Bengaluru  Personal Care         1
# 4        10005       C1262  BigBasket Now  Bengaluru      Household         6
# 7        10008       C1220      Instamart       Pune          fruit         6
# 8        10009       C1093      Instamart     Mumbai         Fruits         3
# ...        ...         ...            ...        ...            ...       ...
# 1007     10008       C1220      Instamart       Pune          fruit         6
# 1008     10009       C1093      Instamart     Mumbai         Fruits         3
# 1010     10011       C1077        Blinkit     Mumbai      Beverages         1
# 1013     10014       C1168          Zepto  Hyderabad      Household         4
# 1014     10015       C1132          Zepto       Pune      Beverages         6
#
# ...

# %%
#Orders NOT from Delhi.

df[df['city']!='Delhi']
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 0        10001       C1024        Blinkit  Hyderabad         Fruits         6
# 1        10002       C1030        Blinkit  Bengaluru  Personal Care         1
# 2        10003       C1157            NaN    Chennai      Beverages         4
# 3        10004       C1299  BigBasket Now     Mumbai          Dairy         4
# 4        10005       C1262  BigBasket Now  Bengaluru      Household         6
# ...        ...         ...            ...        ...            ...       ...
# 1015     10016       C1000  BigBasket Now       Pune          Dairy         2
# 1016     10017       C1205        Blinkit       Pune     Vegetables         3
# 1017     10018       C1280          Zepto    Chennai         Fruits         2
# 1018     10019       C1166      Instamart        NaN         Snacks         3
# 1019     10020       C1093        Blinkit  Bengaluru     Vegetables         3
#
# ...

# %%
#orders with NULL ratings
df[df['rating'].isnull()]
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 8        10009       C1093      Instamart     Mumbai         Fruits         3
# 11       10012       C1238  BigBasket Now      Delhi          Dairy         2
# 13       10014       C1168          Zepto  Hyderabad      Household         4
# 43       10044       C1065          Zepto      Delhi         Snacks         6
# 45       10046       C1124        Blinkit  Bengaluru          Dairy         2
# ...        ...         ...            ...        ...            ...       ...
# 995      10996       C1240        Blinkit  Bengaluru  Personal Care         1
# 996      10997       C1133          Zepto       Pune      Household         1
# 1008     10009       C1093      Instamart     Mumbai         Fruits         3
# 1011     10012       C1238  BigBasket Now      Delhi          Dairy         2
# 1013     10014       C1168          Zepto  Hyderabad      Household         4
#
# ...

# %%
#orders with missing cities

df[df['city'].isnull()]
# Out:
#       order_id customer_id       platform city       category  quantity   mrp  \
# 18       10019       C1166      Instamart  NaN         Snacks         3   639
# 59       10060       C1163  BigBasket Now  NaN      Household         2   349
# 88       10089       C1186          Zepto  NaN  Personal Care         2   178
# 118      10119       C1141          Zepto  NaN  Personal Care         3   288
# 149      10150       C1280      Instamart  NaN      Beverages         5   493
# 240      10241       C1205        Blinkit  NaN      Household         6   416
# 297      10298       C1120      Instamart  NaN         Snacks         8   243
# 317      10318       C1256  BigBasket Now  NaN     Vegetables         1   309
# 331      10332       C1173  BigBasket Now  NaN      Household         4   138
# 353      10354       C1072  BigBasket Now  NaN  Personal Care         7   138
# 447      10448       C1194        Blinkit  NaN         Snacks         2   424
# ...

# %%
df.query("platform=='Blinkit' | platform=='Zepto'")
# Out:
#       order_id customer_id platform       city       category  quantity   mrp  \
# 0        10001       C1024  Blinkit  Hyderabad         Fruits         6   703
# 1        10002       C1030  Blinkit  Bengaluru  Personal Care         1   532
# 6        10007       C1252  Blinkit  Bengaluru      Household         5   767
# 10       10011       C1077  Blinkit     Mumbai      Beverages         1   147
# 12       10013       C1185    Zepto       Pune      Beverages         1  1097
# ...        ...         ...      ...        ...            ...       ...   ...
# 1013     10014       C1168    Zepto  Hyderabad      Household         4   496
# 1014     10015       C1132    Zepto       Pune      Beverages         6    97
# 1016     10017       C1205  Blinkit       Pune     Vegetables         3   720
# 1017     10018       C1280    Zepto    Chennai         Fruits         2  1011
# 1019     10020       C1093  Blinkit  Bengaluru     Vegetables         3  1112
#
# ...

# %%
#standardize platform names
df['platform'] = df['platform'].str.strip().str.lower()
df['city']=df['city'].str.strip().str.lower()

# %%
#unique city names
df['city'].unique()
# Out:
# array(['hyderabad', 'bengaluru', 'chennai', 'mumbai', 'delhi', 'pune',
#        nan], dtype=object)

# %%
#fill missing value with median
df['delivery_fee'] = df['delivery_fee'].fillna(df['delivery_fee'].median())

# %%
#fill missing membership with None

df['membership']=df['membership'].fillna('None')

# %%
df.head()
# Out:
#    order_id customer_id       platform       city       category  quantity  \
# 0     10001       C1024        blinkit  hyderabad         Fruits         6
# 1     10002       C1030        blinkit  bengaluru  Personal Care         1
# 2     10003       C1157            NaN    chennai      Beverages         4
# 3     10004       C1299  bigbasket now     mumbai          Dairy         4
# 4     10005       C1262  bigbasket now  bengaluru      Household         6
#
#    mrp  selling_price  discount_percent  delivery_fee  promised_time  \
# 0  703         667.85                 5          49.0             25
# 1  532         532.00                 0          49.0             30
# 2  335         268.00                20          29.0             10
# 3  915         640.50                30          19.0             20
# 4  629         503.20                20          19.0             10
#
#    delivery_time  order_value payment_mode membership coupon_used weekend  \
# ...

# %%
#duplicate order id's 

df[df.duplicated('order_id')]
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 1000     10001       C1024        blinkit  hyderabad         Fruits         6
# 1001     10002       C1030        blinkit  bengaluru  Personal Care         1
# 1002     10003       C1157            NaN    chennai      Beverages         4
# 1003     10004       C1299  bigbasket now     mumbai          Dairy         4
# 1004     10005       C1262  bigbasket now  bengaluru      Household         6
# 1005     10006       C1047      instamart      delhi  Personal Care         2
# 1006     10007       C1252        blinkit  bengaluru      Household         5
# 1007     10008       C1220      instamart       pune          fruit         6
# 1008     10009       C1093      instamart     mumbai         Fruits         3
# 1009     10010       C1053  bigbasket now       pune         Snacks         1
# 1010     10011       C1077        blinkit     mumbai      Beverages         1
# ...

# %%
#rename deliver_fee to deliver_charge

df.rename(columns={"delivery_fee":"delivery_charge"})
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 0        10001       C1024        blinkit  hyderabad         Fruits         6
# 1        10002       C1030        blinkit  bengaluru  Personal Care         1
# 2        10003       C1157            NaN    chennai      Beverages         4
# 3        10004       C1299  bigbasket now     mumbai          Dairy         4
# 4        10005       C1262  bigbasket now  bengaluru      Household         6
# ...        ...         ...            ...        ...            ...       ...
# 1015     10016       C1000  bigbasket now       pune          Dairy         2
# 1016     10017       C1205        blinkit       pune     Vegetables         3
# 1017     10018       C1280          zepto    chennai         Fruits         2
# 1018     10019       C1166      instamart        NaN         Snacks         3
# 1019     10020       C1093        blinkit  bengaluru     Vegetables         3
#
# ...

# %%
#sort by platform first then delivery time 

df.sort_values(['platform','delivery_time'],ascending=True)
# Out:
#      order_id customer_id       platform       city       category  quantity  \
# 675     10676       C1077  bigbasket now  bengaluru         Snacks         3
# 957     10958       C1079  bigbasket now    chennai          Dairy         7
# 113     10114       C1204  bigbasket now  hyderabad      Beverages         1
# 455     10456       C1040  bigbasket now     mumbai         Fruits         7
# 906     10907       C1284  bigbasket now  hyderabad     Vegetables         8
# ..        ...         ...            ...        ...            ...       ...
# 289     10290       C1234            NaN  bengaluru      Beverages         1
# 443     10444       C1190            NaN  bengaluru  Personal Care         1
# 649     10650       C1165            NaN  hyderabad     Vegetables         5
# 211     10212       C1179            NaN  bengaluru      Beverages         7
# 158     10159       C1047            NaN     mumbai          Dairy         6
#
# ...

# %%
#convert cities to title case

df['city'].str.title()
# Out:
# 0       Hyderabad
# 1       Bengaluru
# 2         Chennai
# 3          Mumbai
# 4       Bengaluru
#           ...
# 1015         Pune
# 1016         Pune
# 1017      Chennai
# 1018          NaN
# 1019    Bengaluru
# Name: city, Length: 1020, dtype: object

# %%
#Find platforms containing 'blink'.

df[df['platform'].str.contains('blink', na=False)]
# Out:
#       order_id customer_id platform       city       category  quantity   mrp  \
# 0        10001       C1024  blinkit  hyderabad         Fruits         6   703
# 1        10002       C1030  blinkit  bengaluru  Personal Care         1   532
# 6        10007       C1252  blinkit  bengaluru      Household         5   767
# 10       10011       C1077  blinkit     mumbai      Beverages         1   147
# 16       10017       C1205  blinkit       pune     Vegetables         3   720
# ...        ...         ...      ...        ...            ...       ...   ...
# 1001     10002       C1030  blinkit  bengaluru  Personal Care         1   532
# 1006     10007       C1252  blinkit  bengaluru      Household         5   767
# 1010     10011       C1077  blinkit     mumbai      Beverages         1   147
# 1016     10017       C1205  blinkit       pune     Vegetables         3   720
# 1019     10020       C1093  blinkit  bengaluru     Vegetables         3  1112
#
# ...

# %%
#Sort by order value descending

df.sort_values('selling_price',ascending=False)
# Out:
#      order_id customer_id       platform       city       category  quantity  \
# 579     10580       C1258        Blinkit      Delhi  Personal Care         6
# 676     10677       C1016  BigBasket Now  Bengaluru         Snacks         1
# 365     10366       C1259        Blinkit  Bengaluru  Personal Care         2
# 734     10735       C1132      Instamart  Bengaluru         Fruits         8
# 955     10956       C1043        Blinkit  Bengaluru      Beverages         8
# ..        ...         ...            ...        ...            ...       ...
# 281     10282       C1205          Zepto  Bengaluru      Household         1
# 960     10961       C1265      Instamart       Pune     Vegetables         6
# 409     10410       C1190          Zepto       Pune         Snacks         2
# 226     10227       C1091      Instamart       Pune      Beverages         5
# 831     10832       C1164        Blinkit     Mumbai  Personal Care         7
#
# ...

# %%
#Convert platform names to uppercase.

df['platform']=df['platform'].str.upper()

# %%
#Convert cities to title case.
df['city']=df['city'].str.title()

# %%
#Find platforms containing 'blink'.

df[df['platform'].str.contains('blink', case=False, na=False)]
# Out:
#       order_id customer_id platform       city       category  quantity   mrp  \
# 0        10001       C1024  BLINKIT  Hyderabad         Fruits         6   703
# 1        10002       C1030  BLINKIT  Bengaluru  Personal Care         1   532
# 6        10007       C1252  BLINKIT  Bengaluru      Household         5   767
# 10       10011       C1077  BLINKIT     Mumbai      Beverages         1   147
# 16       10017       C1205  BLINKIT       Pune     Vegetables         3   720
# ...        ...         ...      ...        ...            ...       ...   ...
# 1001     10002       C1030  BLINKIT  Bengaluru  Personal Care         1   532
# 1006     10007       C1252  BLINKIT  Bengaluru      Household         5   767
# 1010     10011       C1077  BLINKIT     Mumbai      Beverages         1   147
# 1016     10017       C1205  BLINKIT       Pune     Vegetables         3   720
# 1019     10020       C1093  BLINKIT  Bengaluru     Vegetables         3  1112
#
# ...

# %%
#Create high_value_order (>=1000).

df['high_value_order']=df[df['selling_price']>=1000]

# %%
#Create rating_category (Good/Poor).

df['rating_category']=np.where(df['rating']>=4,'Good','Poor')

# %%
#Replace Yes/No with True/False in coupon_used.

df['coupon_used']=np.where(df['coupon_used']=='Yes',True,False)

# %%
#Replace membership None with Standard.
df['membership']=df['membership'].fillna('Standard')

# %%
df[df['membership']=='Standard']
# Out:
#       order_id customer_id       platform     city    category  quantity  \
# 2        10003       C1157            NaN  Chennai   Beverages         4
# 3        10004       C1299  BigBasket Now   Mumbai       Dairy         4
# 11       10012       C1238  BigBasket Now    Delhi       Dairy         2
# 12       10013       C1185          Zepto     Pune   Beverages         1
# 15       10016       C1000  BigBasket Now     Pune       Dairy         2
# ...        ...         ...            ...      ...         ...       ...
# 1012     10013       C1185          Zepto     Pune   Beverages         1
# 1015     10016       C1000  BigBasket Now     Pune       Dairy         2
# 1016     10017       C1205        Blinkit     Pune  Vegetables         3
# 1017     10018       C1280          Zepto  Chennai      Fruits         2
# 1018     10019       C1166      Instamart      NaN      Snacks         3
#
#        mrp  selling_price  discount_percent  delivery_fee  promised_time  \
# ...

# %%
#Average order value by platform

df.groupby('platform')['selling_price'].mean().round()
# Out:
# platform
# BigBasket Now    538.0
# Blinkit          532.0
# Instamart        530.0
# Zepto            510.0
# blinkit          586.0
# Name: selling_price, dtype: float64

# %%
#Average delivery time by platform.

df.groupby('platform')['delivery_time'].mean().round()
# Out:
# platform
# BigBasket Now    26.0
# Blinkit          26.0
# Instamart        26.0
# Zepto            26.0
# blinkit          29.0
# Name: delivery_time, dtype: float64

# %%
#Count orders by city.
df.groupby('city')['order_id'].count().reset_index()
# Out:
#         city  order_id
# 0   Chennai         15
# 1  Bengaluru       165
# 2    Chennai       163
# 3      Delhi       138
# 4  Hyderabad       165
# 5     Mumbai       170
# 6       Pune       178

# %%
#Average order value by city.

df.groupby('city')['order_value'].mean().round().reset_index()
# Out:
#         city  order_value
# 0   Chennai        2609.0
# 1  Bengaluru       2371.0
# 2    Chennai       2303.0
# 3      Delhi       2287.0
# 4  Hyderabad       2413.0
# 5     Mumbai       2274.0
# 6       Pune       2240.0

# %%
#Highest order value in each city.

df.groupby('city')['order_value'].max().reset_index()
# Out:
#         city  order_value
# 0   Chennai        8624.0
# 1  Bengaluru       8968.0
# 2    Chennai       7856.0
# 3      Delhi       8976.0
# 4  Hyderabad       7833.0
# 5     Mumbai       8015.0
# 6       Pune       7866.0

# %%
# Total revenue by platform.

df.groupby('platform')['order_value'].sum().reset_index()
# Out:
#         platform  order_value
# 0  BigBasket Now    600635.30
# 1        Blinkit    569392.65
# 2      Instamart    555500.80
# 3          Zepto    552328.35
# 4        blinkit     42778.30

# %%
#Average discount by category.

df.groupby('category')['discount_percent'].mean()
# Out:
# category
# Beverages        15.245399
# Dairy            15.129870
# Fruits           14.532374
# Household        16.443662
# Personal Care    14.292035
# Snacks           14.035714
# Vegetables       16.075949
# fruit            12.727273
# Name: discount_percent, dtype: float64

# %%
#. Platform with highest average rating.

df.groupby('platform')['rating'].mean().idxmax()
# Out:
# 'Blinkit'

# %%
#City with highest average delivery fee

df.groupby('city')['delivery_fee'].mean().idxmax()
# Out:
# 'Bengaluru'

# %%
#Average delivery time by payment mode.

df2=df.groupby('payment_mode')['delivery_time'].mean().reset_index()

# %%
#top value
df2.sort_values('delivery_time',ascending=False).head(1)
# Out:
#   payment_mode  delivery_time
# 3       Wallet      27.011952

# %%
#Platform-wise total number of orders.

df.groupby('platform')['order_id'].count()
# Out:
# platform
# BigBasket Now    253
# Blinkit          240
# Instamart        229
# Zepto            253
# blinkit           20
# Name: order_id, dtype: int64

# %%
#Highest rated category.

df.groupby('category')['rating'].mean().idxmax()
# Out:
# 'Beverages'

# %%
#Most common payment mode per platform.

df.groupby('platform')['payment_mode'].count()
# Out:
# platform
# BigBasket Now    253
# Blinkit          240
# Instamart        229
# Zepto            253
# blinkit           20
# Name: payment_mode, dtype: int64

# %%
#Find top 5 customers by spending.

df.groupby('customer_id')['order_id'].count().head(5).reset_index()
# Out:
#   customer_id  order_id
# 0       C1000         7
# 1       C1001         8
# 2       C1002         2
# 3       C1003         6
# 4       C1004         2

# %%
#Which platform is fastest on average?

fastest=df.groupby('platform')['delivery_time'].mean()
fastest.sort_values(ascending=False).head(1)

#ans : BlinkIT
# Out:
# platform
# blinkit    29.0
# Name: delivery_time, dtype: float64

# %%
#Does coupon usage increase order value?

df.groupby('coupon_used')['order_value'].mean().reset_index()

#False Indicates that when coupon isnt used , then the order
#value cost increases!
# Out:
#    coupon_used  order_value
# 0        False  2404.124248
# 1         True  2233.557486

# %% [markdown]
# FINAL CHALLENGE

# %% [markdown]
# Clean the dataset from scratch without looking at notes.

# %%
print(df.info(),end='\n')
print("the shape is",df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1020 non-null   int64
#  1   customer_id       1020 non-null   object
#  2   platform          995 non-null    object
#  3   city              994 non-null    object
#  4   category          1020 non-null   object
#  5   quantity          1020 non-null   int64
#  6   mrp               1020 non-null   int64
#  7   selling_price     1020 non-null   float64
#  8   discount_percent  1020 non-null   int64
#  9   delivery_fee      995 non-null    float64
#  10  promised_time     1020 non-null   int64
#  11  delivery_time     1020 non-null   int64
#  12  order_value       1020 non-null   float64
#  13  payment_mode      1020 non-null   object
#  14  membership        1020 non-null   object
#  15  coupon_used       1020 non-null   bool
# ...

# %% [markdown]
# Observations :
# NULL values present in platform,city,category,delivery_fee,rating

# %%
df.groupby('city')['order_id'].count().reset_index()
# Out:
#         city  order_id
# 0   Chennai         15
# 1  Bengaluru       165
# 2    Chennai       163
# 3      Delhi       138
# 4  Hyderabad       165
# 5     Mumbai       170
# 6       Pune       178

# %% [markdown]
# Observations: IN consistent names : Chennai and Chennai exist twice , idk why

# %%
df['city']=df['city'].str.strip().str.title()

#consistent City namings

# %%
df.groupby('platform')['order_id'].count().reset_index()
# Out:
#         platform  order_id
# 0  BigBasket Now       253
# 1        Blinkit       240
# 2      Instamart       229
# 3          Zepto       253
# 4        blinkit        20

# %% [markdown]
# Observations: blinkit repeated twice. one as Blinkit , another as blinkit

# %%
df['platform']=df['platform'].str.strip().str.title()

#consistent platform naming

# %%
df[df['delivery_fee'].isnull()]
# Out:
#      order_id customer_id       platform       city       category  quantity  \
# 99      10100       C1050            NaN  Bengaluru      Household         7
# 103     10104       C1205          Zepto      Delhi         Snacks         4
# 154     10155       C1284  BigBasket Now       Pune          Dairy         1
# 193     10194       C1262      Instamart       Pune         Snacks         1
# 194     10195       C1228        Blinkit  Hyderabad         Snacks         2
# 255     10256       C1021  BigBasket Now  Bengaluru         Snacks         5
# 283     10284       C1279      Instamart      Delhi         Snacks         1
# 354     10355       C1082      Instamart      Delhi     Vegetables         5
# 387     10388       C1096          Zepto    Chennai      Beverages         4
# 423     10424       C1243  BigBasket Now    Chennai     Vegetables         7
# 431     10432       C1065          Zepto  Bengaluru     Vegetables         8
# ...

# %% [markdown]
# delivery fee is given as null . we can just give it the median price,if the subscription isnt gold or silver.

# %%
median_price=df['delivery_fee'].median()
condition=df['delivery_fee'].isnull()|df['membership'].isin(['Gold','Silver'])
df['delivery_fee']=np.where(condition,0,median_price)

# %%
df[df['rating'].isnull()]
# Out:
#       order_id customer_id       platform       city       category  quantity  \
# 8        10009       C1093      Instamart     Mumbai         Fruits         3
# 11       10012       C1238  Bigbasket Now      Delhi          Dairy         2
# 13       10014       C1168          Zepto  Hyderabad      Household         4
# 43       10044       C1065          Zepto      Delhi         Snacks         6
# 45       10046       C1124        Blinkit  Bengaluru          Dairy         2
# ...        ...         ...            ...        ...            ...       ...
# 995      10996       C1240        Blinkit  Bengaluru  Personal Care         1
# 996      10997       C1133          Zepto       Pune      Household         1
# 1008     10009       C1093      Instamart     Mumbai         Fruits         3
# 1011     10012       C1238  Bigbasket Now      Delhi          Dairy         2
# 1013     10014       C1168          Zepto  Hyderabad      Household         4
#
# ...

# %% [markdown]
# NULL values in ratings solution : add median value / mean value rating or fill it with 0

# %%
df[df['rating'].isnull()]=df['rating'].median()
# Out:
# C:\Users\titan\AppData\Local\Temp\ipykernel_7440\2980768113.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df[df['rating'].isnull()]=df['rating'].median()

# %% [markdown]
# (2) PRODUCE A CLEANED DataFrame

# %%
df2=df

# %%
df2.groupby('platform')['order_id'].count() #its clean as it had errors in initial DF before cleaning !
# Out:
# platform
# 3.0              185
# Bigbasket Now    201
# Blinkit          215
# Instamart        189
# Zepto            206
# Name: order_id, dtype: int64

# %% [markdown]
# 3. Answer: Which platform would you recommend and why? #customer POV
#
# whichever quick-commerce platform provides the best overall customer value based on delivery efficiency, customer satisfaction and pricing(delivery fee OR money from subscription)
#
# least avg delivery time (25.87) - BigBasket Now
# highest avg rating(3.158140) - Blinkit
# highest PROFIT via delivery metrics alone - Blinkit
# highest good : poor ratio
# Bigbasket 0.38222222222222224
# Blinkit 0.8220338983050848
# Instamart 0.7027027027027027
# Zepto 0.4507042253521127-> Blinkit wins

# %%
df.groupby('platform')['delivery_time'].mean().reset_index()
#checking delivery time
# Out:
#         platform  delivery_time
# 0  Bigbasket Now      25.875622
# 1        Blinkit      26.572093
# 2      Instamart      26.280423
# 3          Zepto      26.000000

# %%
df.groupby('platform')['rating'].mean() #rating check
# Out:
# platform
# Bigbasket Now    3.089552
# Blinkit          3.158140
# Instamart        2.962963
# Zepto            2.805825
# Name: rating, dtype: float64

# %%
conditions = [
    df['membership'] == 'gold',
    df['membership'] == 'silver'
]

# 2. Match them with your choices list
profit = [50, 25]

# 3. Pass both lists directly into np.select
df['profits'] = np.select(conditions, profit, default=df['delivery_fee'])
# Out:
# C:\Users\titan\AppData\Local\Temp\ipykernel_7440\1453946758.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['profits'] = np.select(conditions, profit, default=df['delivery_fee'])

# %%
df.groupby('platform')['profits'].sum()
# Out:
# platform
# Bigbasket Now    1740.0
# Blinkit          2088.0
# Instamart        1624.0
# Zepto            2001.0
# Name: profits, dtype: float64

# %%
df.groupby(['platform','rating_category'])['order_id'].count()
# Out:
# platform       rating_category
# Bigbasket Now  Good                86
#                Poor               115
# Blinkit        Good                97
#                Poor               118
# Instamart      Good                78
#                Poor               111
# Zepto          Good                64
#                Poor               142
# Name: order_id, dtype: int64

# %%
print('Bigbasket',86/225)
print("Blinkit",97/118)
print("Instamart",78/111)
print("Zepto",64/142)
# Out:
# Bigbasket 0.38222222222222224
# Blinkit 0.8220338983050848
# Instamart 0.7027027027027027
# Zepto 0.4507042253521127

# %% [markdown]
# From a customer perspective, Blinkit demonstrates the strongest overall performance by combining high customer satisfaction with the highest proportion of positive experiences. Although BigBasket Now records the fastest average delivery time, Blinkit's balance across multiple customer-centric metrics makes it the strongest overall recommendation within this dataset. (same as q7)

# %% [markdown]
# Q4. Which city should operations improve first?

# %% [markdown]
# CITY THAT has low ratings , customers , lower delivery times and lower no of deliveries

# %%
df.groupby('city')['order_id'].count() #delhi has least customers too!
# Out:
# city
# Bengaluru    136
# Chennai      144
# Delhi        104
# Hyderabad    139
# Mumbai       134
# Pune         154
# Name: order_id, dtype: int64

# %%
df.groupby('city')['rating'].mean() #delhi has the LEAST OVERALL rating followed by mum
# Out:
# city
# Bengaluru    3.022059
# Chennai      3.159722
# Delhi        2.788462
# Hyderabad    3.086331
# Mumbai       2.888060
# Pune         3.012987
# Name: rating, dtype: float64

# %%
df.groupby('city')['delivery_time'].mean() #mumbai takes the longest , followed by delhi
# Out:
# city
# Bengaluru    25.904412
# Chennai      25.576389
# Delhi        26.894231
# Hyderabad    25.395683
# Mumbai       27.044776
# Pune         25.889610
# Name: delivery_time, dtype: float64

# %%
df.groupby('city')['profits'].sum() #delhi has the least delivery-profit
# Out:
# city
# Bengaluru    1044.0
# Chennai      1247.0
# Delhi         870.0
# Hyderabad    1247.0
# Mumbai       1189.0
# Pune         1798.0
# Name: profits, dtype: float64

# %%
df.groupby(['city','rating_category'])['order_id'].count() /69)
print("mumbai good:bad ratio",51/83)
print("delhi good:bad ratio",35/69)
#delhi has the lowest ratio , 0.5072463768115942
# Out:
# city       rating_category
# Bengaluru  Good               51
#            Poor               85
# Chennai    Good               66
#            Poor               78
# Delhi      Good               35
#            Poor               69
# Hyderabad  Good               62
#            Poor               77
# Mumbai     Good               51
#            Poor               83
# Pune       Good               60
#            Poor               94
# Name: order_id, dtype: int64

# %% [markdown]
# delhi should be a major city that improves operations first , due to lower customer satisfaction compared to others , lower ratio of good reviews:bad reviews while experiencing long delivery times

# %% [markdown]
# List limitations of the dataset.
#
# synthetic-many rows had "3.0" as their platform-irregular naming/spacing
