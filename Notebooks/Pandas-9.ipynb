# %%
//EXTRAS

# %%
df.value_counts() 

counts how many times each element occurs

df['Country'].value_counts()

op:
USA       452
Canada    210
France     98
Name: Country, dtype: int64

# %%
pd.concat([dataframes])

# Stack jan_df and feb_df on top of each other (axis=0 is default)
master_df = pd.concat([jan_df, feb_df], axis=0)

# Glue them side-by-side instead (add columns)
wide_df = pd.concat([df1, df2], axis=1)

# %%
pivot table - The Summarizer
# Create a summary grid
summary = df.pivot_table(
    index='Year', 
    columns='Region', 
    values='Sales', 
    aggfunc='sum'
)
Aggregates and reshapes data into a summary grid.
