# %% [markdown]
# #ROW SELECTIONS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# to change an index , do df.set_index(column)

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\titan\OneDrive\Desktop\world_population_excel_workbook.xlsx",sheet_name=1)
print(df.head(10))

print(df.iloc[0:3]) #iloc returns the rows
# Out:
#    Rank CCA3              Country           Capital
# 0    36  AFG          Afghanistan             Kabul
# 1   138  ALB              Albania            Tirana
# 2    34  DZA              Algeria           Algiers
# 3   213  ASM       American Samoa         Pago Pago
# 4   203  AND              Andorra  Andorra la Vella
# 5    42  AGO               Angola            Luanda
# 6   224  AIA             Anguilla        The Valley
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s
# 8    33  ARG            Argentina      Buenos Aires
# 9   140  ARM              Armenia           Yerevan
#    Rank CCA3      Country  Capital
# 0    36  AFG  Afghanistan    Kabul
# 1   138  ALB      Albania   Tirana
# 2    34  DZA      Algeria  Algiers

# %%
print(df.loc[2:5,:])
LOC[row,column] is the syntax!
# Out:
#    Rank CCA3         Country           Capital
# 2    34  DZA         Algeria           Algiers
# 3   213  ASM  American Samoa         Pago Pago
# 4   203  AND         Andorra  Andorra la Vella
# 5    42  AGO          Angola            Luanda

# %%
df2=df.set_index('CCA3')
print(df.loc[1:,'Country'])
# Out:
# 1                Albania
# 2                Algeria
# 3         American Samoa
# 4                Andorra
# 5                 Angola
#              ...
# 229    Wallis and Futuna
# 230       Western Sahara
# 231                Yemen
# 232               Zambia
# 233             Zimbabwe
# Name: Country, Length: 233, dtype: object
