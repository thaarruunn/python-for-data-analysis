# %% [markdown]
# #Reading Data into Pandas.

# %%
import pandas as pd

# %%
(1) CSV :

if unicode errors exist: use ebcoding pd.read_csv("sales.csv", encoding='latin1')
pd.read_csv(url)

# %%
(2) Excel :

install a pip : openpyxl

pd.read_excel(url)

#read only a specific cell:

    df.read_excel("sales.xlsx",sheet_name="January")

#read by sheet number:

    df.read_excel("salex.xlsx",sheet_name=0)

# %%
(3)JSON :

pd.read_json(json data)

# %%
(4)SQL:

pd.read_sql(query,connection)

# %%
(4) Reading from URL's :
eg : url = "https://raw.githubusercontent.com/..."
     df=pd.read_csv(url)

# %%
# to read only some columns:
df = pd.read_csv("sales.csv",usecols=['Name','Salary'])

#to only read the first 100 rows:
df=pd.read_csv("sales.csv",nrows=100)

#custom delimiters:

df=pd.read_csv("sales.csv",sep='\t')

# %%
PANDAS hides columns

do:
pd.set_option("display.max.columns",100)
pd.set_option("display.max.rows",50)

# %%
To save into a CSV file:
import pandas as pd

#creates and saves a file as sales report
df.to_csv('sales_report.csv', index=False)

extras to know:

# Saves as a Tab-Separated Values (TSV) file
df.to_csv('sales_report.tsv', sep='\t', index=False)

#handles null values
df.to_csv('sales_report.csv', index=False, na_rep='N/A')

# %%
To save into a Excel file:

#saves into an excel file
df.to_excel('sales_report.xlsx', index=False, sheet_name='Sales Summary')

# Create an Excel file container
with pd.ExcelWriter('corporate_report.xlsx') as writer:
    df_sales.to_excel(writer, sheet_name='Sales Performance', index=False)
    df_regions.to_excel(writer, sheet_name='Regional Targets', index=False)
    df_meta.to_excel(writer, sheet_name='Metadata Logs', index=False)

# %%
# FILE HANDLING SUMMARY SHEET:

pd.read_csv()

pd.read_excel()

# INSPECT

df.head()

df.tail()

df.shape

df.columns

df.info()

df.describe()

df.dtypes

# DISPLAY

pd.set_option('display.max_columns',None)

pd.set_option('display.max_rows',None)

pd.set_option('display.max_colwidth',None)

# CLEAN

df.isnull().sum()

df.fillna()

df.dropna()

df.drop_duplicates()

# TYPES

df.astype()

pd.to_datetime()

# SAVE

df.to_csv(index=False)

df.to_excel(index=False)

# FILES

os.getcwd()

os.listdir()

os.path.exists()
