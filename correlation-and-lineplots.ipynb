# %% [markdown]
# <strong>Scatter plots and correlations / relations analysis</strong>

# %% [markdown]
# *usually for numeric value v/s numeric value - use scatter plot*

# %%
#scatter plot code

fig,axis=plt.subplots(figsize=(5,3))
axis.scatter(df['time_studied'],df['marks'])
axis.set_title('correlation between no of hrs studies vs marks')
axis.set_xlabel('no of hours studies')
axis.set_ylabel('marks scored')
plt.show()

# %% [markdown]
# <strong> ways to read a line plot / correlation </strong>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# adding more than 2 variables

ax.scatter(
    df["discount_percent"],
    df["order_value"],
    s=df["quantity"]*10
)

#size:quantity

# %%
discount=[5,15,16,18,25]
order_value=[500,1000,1100,1500,2500]
quantity=[1,2,5,7,8]

# %%
import matplotlib.pyplot as plt

fig,axis=plt.subplots(figsize=(5,3))
axis.scatter(order_value,discount)
plt.show()

# %%
import matplotlib.pyplot as plt

fig,axis=plt.subplots(figsize=(5,3))
axis.scatter(order_value,discount,s=quantity)
plt.show()

# %% [markdown]
# #with no of quantity as size

# %% [markdown]
# <strong>Alpha is a transparent parameter that avoids any overlapping!</strong>

# %% [markdown]
# ![image.png](attachment:image.png)
